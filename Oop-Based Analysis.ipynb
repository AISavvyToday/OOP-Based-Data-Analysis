# %% [markdown]
# ## Data Modeling
# ### Step 1: Define the Computer Class

# %%
class Computer:
    def __init__(self, CmptrID, CmptrIP, CmptrSite):
        """
        Initialize the Computer object with ID, IP, and Site.
        """
        self.CmptrID = CmptrID
        self.CmptrIP = CmptrIP
        self.CmptrSite = CmptrSite

    def cmptrToString(self):
        return f"Computer ID: {self.CmptrID}, IP: {self.CmptrIP}, Site: {self.CmptrSite}"

    def displayCmptr(self):
        print(self.cmptrToString())

# %% [markdown]
# ### Step 2: Message Class

# %%
class Message:
    def __init__(self, MsgPriority, MsgTo, Msg, MsgSend, MsgRec, MsgSubj):
        """
        Initialize the Message object with Priority, To, Content, Sender, Receiver, and Subject.
        """
        self.MsgPriority = MsgPriority
        self.MsgTo = MsgTo
        self.Msg = Msg
        self.MsgSend = MsgSend
        self.MsgRec = MsgRec
        self.MsgSubj = MsgSubj

    def msgToString(self):
        return f"Message Priority: {self.MsgPriority}, To: {self.MsgTo}, Content: {self.Msg}, Sender: {self.MsgSend}, Receiver: {self.MsgRec}, Subject: {self.MsgSubj}"

    def displayMsg(self):
        print(self.msgToString())

# %% [markdown]
# ### Step 3: LogEntry Class

# %%
class LogEntry:
    def __init__(self, LogEntryNumber, LogEntryDTG, SendComputer, ReceiveComputer, Message):
        """
        Initialize LogEntry object with Log Entry Number, Date-Time-Group, Sending Computer, and Receiving Computer.
        """
        self.LogEntryNumber = LogEntryNumber
        self.LogEntryDTG = LogEntryDTG
        self.SendComputer = SendComputer
        self.ReceiveComputer = ReceiveComputer
        self.Message = Message

    def entryToString(self):
        """
        Convert the log entry details to a string format.
        """
        return f"Entry Number: {self.LogEntryNumber}, Entry DTG: {self.LogEntryDTG}, Sending Computer: {self.SendComputer.cmptrToString()}, Receiving Computer: {self.ReceiveComputer.cmptrToString()}, Message: {self.Message.msgToString()}"

    def displayEntry(self):
        """
        Display log entry details.
        """
        print(self.entryToString())

# %% [markdown]
# ## Data Parsing and Object Instantiation
# ### Step 4: Data Parsing Function

# %%
def buildLogEntry(log_line):
    fields = log_line.split("\t")
    if len(fields) >= 8:
        # Parsing Sending Computer Fields
        send_computer_fields = fields[2].split(" ")
        send_computer_cid = send_computer_fields[1][:-1]
        send_computer_ip = send_computer_fields[3][:-1]
        send_computer_site = send_computer_fields[5]

        send_computer = Computer(send_computer_cid, send_computer_ip, send_computer_site)

        # Parsing Receiving Computer Fields
        receive_computer_fields = fields[3].split(" ")
        receive_computer_cid = receive_computer_fields[1][:-1]
        receive_computer_ip = receive_computer_fields[3][:-1]
        receive_computer_site = receive_computer_fields[5]

        receive_computer = Computer(receive_computer_cid, receive_computer_ip, receive_computer_site)

        # Parsing Message Fields
        msg_priority = fields[4]
        msg_to = fields[5]
        msg_content = fields[6]
        
        msg_send_receive = fields[7].split(" ")
        msg_send = msg_send_receive[1][:-1]
        msg_rec = msg_send_receive[3][:-1]
        
        msg_subj = fields[7].split("SUBJ: ")[1]
        
        message = Message(msg_priority, msg_to, msg_content, msg_send, msg_rec, msg_subj)

        return LogEntry(fields[0], fields[1], send_computer, receive_computer, message)
    else:
        print(f"Skipping line: {log_line}")
        return None

# %% [markdown]
# ### Step 5: Store Log Entries

# %%
log_entries = []

# Read the Pace IT Log file line by line
with open('PaceIT_1.txt', 'r') as file:
    for line in file:
        log_entry = buildLogEntry(line.strip())
        if log_entry is not None:
            log_entries.append(log_entry)

# %% [markdown]
# ## Data Analysis
# ### Step 6: LogEntryAnalysis Class

# %%
class LogEntryAnalysis:
    def __init__(self, analysisID, filename, logEntries):
        self.analysisID = analysisID
        self.filename = filename
        self.logEntries = logEntries

    def descriptive_statistics(self):
        urgent_count = sum(1 for entry in self.logEntries if entry.Message.MsgPriority == 'Urgent')
        print(f"Number of urgent messages: {urgent_count}")

    def computers_and_locations(self):
        locations = {}
        for entry in self.logEntries:
            location = entry.SendComputer.CmptrSite
            if location not in locations:
                locations[location] = 0
            locations[location] += 1
        print("Computers and their Locations:")
        for location, count in locations.items():
            print(f"{location}: {count}")

    def messages_and_routing(self):
        routing = {}
        for entry in self.logEntries:
            sender = entry.SendComputer.CmptrID
            receiver = entry.ReceiveComputer.CmptrID
            pair = (sender, receiver)
            if pair not in routing:
                routing[pair] = 0
            routing[pair] += 1
        print("Messages and their Routing:")
        for (sender, receiver), count in routing.items():
            print(f"{sender} -> {receiver}: {count} messages")

    def message_content(self):
        subject_count = {}
        for entry in self.logEntries:
            subject = entry.Message.MsgSubj
            if subject not in subject_count:
                subject_count[subject] = 0
            subject_count[subject] += 1
        print("Message Subjects and their Counts:")
        for subject, count in subject_count.items():
            print(f"{subject}: {count}")

    def date_time_groups(self):
        date_count = {}
        for entry in self.logEntries:
            date = entry.LogEntryDTG.split(' ')[0]
            if date not in date_count:
                date_count[date] = 0
            date_count[date] += 1
        print("Log Entries by Date:")
        for date, count in date_count.items():
            print(f"{date}: {count} entries")

# %% [markdown]
# ### Step 7: Analysis

# %%
if __name__ == "__main__":
    # Instantiate object
    log_analysis = LogEntryAnalysis("Analysis_1", "PaceIT_1.txt", log_entries)
    # Generate Reports and Insights
    print("Descriptive Statistics")
    log_analysis.descriptive_statistics()

    print("\n Computers and their Locations")
    log_analysis.computers_and_locations()

    print("\n Messages and their Routing ")
    log_analysis.messages_and_routing()

    print("\n Message Content Analysis ")
    log_analysis.message_content()

    print("\n Date Time Groups Analysis ")
    log_analysis.date_time_groups()
# Out:
# Descriptive Statistics
# Number of urgent messages: 310
#
#  Computers and their Locations
# Computers and their Locations:
# Pleasantville: 348
# New: 329
# White: 323
#
#  Messages and their Routing
# Messages and their Routing:
# Pace_66_1 -> Pace_12_: 1 messages
# Pace_43_1 -> Pace_76_1: 1 messages
# Pace_75_1 -> Pace_28_1: 1 messages
# Pace_61_1 -> Pace_76_2: 1 messages
# Pace_79_1 -> Pace_64_2: 1 messages
# Pace_12_1 -> Pace_82_: 1 messages
# Pace_31_1 -> Pace_38_1: 1 messages
# Pace_65_ -> Pace_15_1: 1 messages
# Pace_18_ -> Pace_73_2: 1 messages
# Pace_26_1 -> Pace_98_1: 1 messages
# Pace_42_ -> Pace_17_: 1 messages
# Pace_74_2 -> Pace_14_: 1 messages
# Pace_55_ -> Pace_93_2: 1 messages
# Pace_31_2 -> Pace_40_: 1 messages
# Pace_66_2 -> Pace_94_: 1 messages
# Pace_71_1 -> Pace_53_1: 1 messages
# Pace_75_1 -> Pace_13_2: 1 messages
# Pace_67_ -> Pace_63_: 1 messages
# Pace_80_1 -> Pace_68_1: 1 messages
# Pace_70_1 -> Pace_45_1: 1 messages
# Pace_39_1 -> Pace_64_: 1 messages
# Pace_80_1 -> Pace_48_: 1 messages
# Pace_38_2 -> Pace_32_2: 1 messages
# Pace_96_ -> Pace_50_1: 1 messages
# Pace_62_2 -> Pace_57_: 1 messages
# Pace_18_1 -> Pace_27_: 1 messages
# Pace_63_2 -> Pace_64_2: 1 messages
# Pace_70_1 -> Pace_61_: 1 messages
# Pace_48_ -> Pace_64_1: 1 messages
# Pace_43_ -> Pace_24_1: 1 messages
# Pace_30_2 -> Pace_16_1: 1 messages
# Pace_21_2 -> Pace_73_: 1 messages
# Pace_66_2 -> Pace_67_1: 1 messages
# Pace_95_1 -> Pace_54_: 1 messages
# Pace_84_1 -> Pace_52_: 1 messages
# Pace_45_ -> Pace_72_: 1 messages
# Pace_62_ -> Pace_95_1: 1 messages
# Pace_95_1 -> Pace_74_2: 1 messages
# Pace_29_1 -> Pace_12_2: 1 messages
# Pace_10_ -> Pace_18_2: 1 messages
# Pace_87_ -> Pace_91_: 1 messages
# Pace_63_1 -> Pace_29_1: 2 messages
# Pace_16_1 -> Pace_72_1: 1 messages
# Pace_62_ -> Pace_68_1: 1 messages
# Pace_79_1 -> Pace_22_: 1 messages
# Pace_70_ -> Pace_26_: 1 messages
# Pace_69_2 -> Pace_25_2: 1 messages
# Pace_14_1 -> Pace_93_: 1 messages
# Pace_66_2 -> Pace_14_1: 1 messages
# Pace_68_1 -> Pace_96_2: 1 messages
# Pace_10_2 -> Pace_67_: 1 messages
# Pace_59_ -> Pace_81_: 1 messages
# Pace_26_1 -> Pace_41_1: 1 messages
# Pace_14_ -> Pace_80_: 1 messages
# Pace_82_ -> Pace_32_2: 1 messages
# Pace_17_1 -> Pace_54_1: 1 messages
# Pace_31_1 -> Pace_37_1: 1 messages
# Pace_44_ -> Pace_13_1: 1 messages
# Pace_84_ -> Pace_60_1: 1 messages
# Pace_30_ -> Pace_53_1: 1 messages
# Pace_16_ -> Pace_15_2: 1 messages
# Pace_11_ -> Pace_57_: 1 messages
# Pace_87_2 -> Pace_25_2: 1 messages
# Pace_43_1 -> Pace_76_: 1 messages
# Pace_98_ -> Pace_43_: 1 messages
# Pace_57_2 -> Pace_31_1: 1 messages
# Pace_24_ -> Pace_58_: 1 messages
# Pace_61_ -> Pace_72_: 1 messages
# Pace_70_1 -> Pace_25_1: 1 messages
# Pace_27_ -> Pace_41_1: 1 messages
# Pace_25_ -> Pace_43_: 1 messages
# Pace_74_ -> Pace_92_2: 1 messages
# Pace_42_2 -> Pace_33_1: 1 messages
# Pace_30_1 -> Pace_78_1: 1 messages
# Pace_85_ -> Pace_98_1: 1 messages
# Pace_37_ -> Pace_62_1: 1 messages
# Pace_54_2 -> Pace_96_2: 1 messages
# Pace_89_1 -> Pace_13_2: 1 messages
# Pace_38_2 -> Pace_54_: 1 messages
# Pace_16_ -> Pace_34_1: 1 messages
# Pace_39_2 -> Pace_97_: 1 messages
# Pace_78_2 -> Pace_87_: 1 messages
# Pace_36_2 -> Pace_52_2: 1 messages
# Pace_51_ -> Pace_92_1: 1 messages
# Pace_95_1 -> Pace_48_2: 1 messages
# Pace_75_1 -> Pace_38_2: 1 messages
# Pace_53_ -> Pace_63_: 1 messages
# Pace_49_1 -> Pace_97_1: 1 messages
# Pace_93_2 -> Pace_15_2: 1 messages
# Pace_47_ -> Pace_64_2: 1 messages
# Pace_44_1 -> Pace_40_: 1 messages
# Pace_59_ -> Pace_40_: 1 messages
# Pace_45_ -> Pace_67_: 1 messages
# Pace_38_ -> Pace_33_1: 1 messages
# Pace_31_1 -> Pace_51_: 1 messages
# Pace_96_ -> Pace_68_1: 1 messages
# Pace_37_1 -> Pace_26_1: 1 messages
# Pace_22_1 -> Pace_22_: 1 messages
# Pace_68_2 -> Pace_86_2: 1 messages
# Pace_90_ -> Pace_31_1: 1 messages
# Pace_36_1 -> Pace_62_2: 1 messages
# Pace_38_2 -> Pace_19_: 1 messages
# Pace_92_1 -> Pace_83_1: 1 messages
# Pace_61_2 -> Pace_17_1: 1 messages
# Pace_19_ -> Pace_26_2: 1 messages
# Pace_37_2 -> Pace_46_1: 1 messages
# Pace_60_ -> Pace_62_2: 1 messages
# Pace_50_ -> Pace_30_2: 1 messages
# Pace_38_2 -> Pace_77_1: 1 messages
# Pace_32_ -> Pace_17_1: 1 messages
# Pace_68_1 -> Pace_14_1: 1 messages
# Pace_93_2 -> Pace_40_: 1 messages
# Pace_60_ -> Pace_86_1: 1 messages
# Pace_65_2 -> Pace_91_: 1 messages
# Pace_49_ -> Pace_37_2: 1 messages
# Pace_81_1 -> Pace_12_: 1 messages
# Pace_35_ -> Pace_38_: 1 messages
# Pace_45_2 -> Pace_52_1: 1 messages
# Pace_91_1 -> Pace_75_2: 1 messages
# Pace_32_1 -> Pace_79_1: 1 messages
# Pace_76_ -> Pace_67_: 1 messages
# Pace_48_2 -> Pace_70_2: 1 messages
# Pace_44_2 -> Pace_61_: 1 messages
# Pace_83_2 -> Pace_46_: 1 messages
# Pace_73_1 -> Pace_27_1: 1 messages
# Pace_91_ -> Pace_86_2: 1 messages
# Pace_91_2 -> Pace_89_1: 1 messages
# Pace_39_1 -> Pace_31_1: 1 messages
# Pace_53_2 -> Pace_18_2: 1 messages
# Pace_92_2 -> Pace_80_: 1 messages
# Pace_81_ -> Pace_35_1: 1 messages
# Pace_45_ -> Pace_29_1: 1 messages
# Pace_68_1 -> Pace_82_1: 1 messages
# Pace_41_1 -> Pace_18_2: 2 messages
# Pace_19_1 -> Pace_40_2: 1 messages
# Pace_90_1 -> Pace_22_: 1 messages
# Pace_85_1 -> Pace_16_1: 1 messages
# Pace_60_1 -> Pace_68_1: 1 messages
# Pace_74_1 -> Pace_94_: 1 messages
# Pace_64_ -> Pace_38_2: 1 messages
# Pace_50_ -> Pace_94_1: 1 messages
# Pace_11_2 -> Pace_64_1: 1 messages
# Pace_18_ -> Pace_47_2: 1 messages
# Pace_35_1 -> Pace_30_2: 1 messages
# Pace_24_ -> Pace_86_1: 1 messages
# Pace_36_1 -> Pace_60_1: 1 messages
# Pace_53_2 -> Pace_80_2: 1 messages
# Pace_76_ -> Pace_17_1: 1 messages
# Pace_84_ -> Pace_84_: 1 messages
# Pace_14_ -> Pace_99_1: 1 messages
# Pace_93_ -> Pace_60_1: 1 messages
# Pace_34_ -> Pace_51_1: 1 messages
# Pace_92_ -> Pace_55_2: 1 messages
# Pace_87_2 -> Pace_61_2: 1 messages
# Pace_51_1 -> Pace_76_: 1 messages
# Pace_43_ -> Pace_29_1: 1 messages
# Pace_92_2 -> Pace_83_1: 1 messages
# Pace_26_ -> Pace_51_: 1 messages
# Pace_24_2 -> Pace_63_: 1 messages
# Pace_11_1 -> Pace_39_2: 1 messages
# Pace_23_1 -> Pace_74_: 1 messages
# Pace_99_ -> Pace_50_2: 1 messages
# Pace_78_1 -> Pace_65_: 1 messages
# Pace_68_ -> Pace_51_1: 1 messages
# Pace_69_2 -> Pace_78_1: 1 messages
# Pace_51_ -> Pace_25_1: 1 messages
# Pace_56_1 -> Pace_93_1: 1 messages
# Pace_53_ -> Pace_34_1: 1 messages
# Pace_76_ -> Pace_82_1: 1 messages
# Pace_51_1 -> Pace_61_1: 1 messages
# Pace_91_1 -> Pace_37_: 1 messages
# Pace_51_1 -> Pace_29_1: 1 messages
# Pace_61_ -> Pace_22_: 1 messages
# Pace_11_1 -> Pace_15_: 1 messages
# Pace_33_1 -> Pace_41_: 1 messages
# Pace_57_ -> Pace_83_: 1 messages
# Pace_26_2 -> Pace_46_: 1 messages
# Pace_17_1 -> Pace_86_1: 1 messages
# Pace_55_1 -> Pace_46_1: 1 messages
# Pace_37_ -> Pace_56_1: 1 messages
# Pace_10_1 -> Pace_18_1: 1 messages
# Pace_37_ -> Pace_79_1: 1 messages
# Pace_54_2 -> Pace_74_: 1 messages
# Pace_65_2 -> Pace_87_1: 1 messages
# Pace_93_ -> Pace_74_: 1 messages
# Pace_96_1 -> Pace_32_2: 1 messages
# Pace_59_ -> Pace_30_2: 1 messages
# Pace_29_2 -> Pace_90_: 1 messages
# Pace_22_2 -> Pace_82_1: 1 messages
# Pace_62_2 -> Pace_39_1: 1 messages
# Pace_77_ -> Pace_38_2: 1 messages
# Pace_80_ -> Pace_45_1: 1 messages
# Pace_99_1 -> Pace_70_1: 1 messages
# Pace_52_2 -> Pace_97_1: 1 messages
# Pace_89_1 -> Pace_10_1: 1 messages
# Pace_31_ -> Pace_19_2: 1 messages
# Pace_44_2 -> Pace_67_1: 1 messages
# Pace_99_2 -> Pace_65_: 1 messages
# Pace_35_1 -> Pace_57_1: 1 messages
# Pace_20_2 -> Pace_12_1: 1 messages
# Pace_91_1 -> Pace_55_: 1 messages
# Pace_31_ -> Pace_13_: 1 messages
# Pace_47_1 -> Pace_85_: 1 messages
# Pace_10_1 -> Pace_88_2: 1 messages
# Pace_69_2 -> Pace_72_2: 1 messages
# Pace_45_2 -> Pace_41_1: 1 messages
# Pace_62_2 -> Pace_83_1: 1 messages
# Pace_19_ -> Pace_93_: 1 messages
# Pace_25_1 -> Pace_66_2: 1 messages
# Pace_48_ -> Pace_13_: 1 messages
# Pace_33_ -> Pace_18_2: 1 messages
# Pace_94_1 -> Pace_59_1: 1 messages
# Pace_70_ -> Pace_56_: 1 messages
# Pace_18_1 -> Pace_74_1: 1 messages
# Pace_20_1 -> Pace_40_2: 1 messages
# Pace_74_1 -> Pace_19_: 1 messages
# Pace_31_ -> Pace_58_1: 1 messages
# Pace_61_1 -> Pace_60_: 1 messages
# Pace_12_ -> Pace_12_1: 1 messages
# Pace_97_ -> Pace_86_1: 1 messages
# Pace_68_2 -> Pace_16_: 1 messages
# Pace_59_1 -> Pace_84_2: 1 messages
# Pace_54_1 -> Pace_67_1: 1 messages
# Pace_90_1 -> Pace_11_: 1 messages
# Pace_76_ -> Pace_33_2: 1 messages
# Pace_81_ -> Pace_48_1: 1 messages
# Pace_66_1 -> Pace_56_1: 1 messages
# Pace_36_ -> Pace_39_2: 1 messages
# Pace_18_2 -> Pace_12_1: 1 messages
# Pace_53_1 -> Pace_15_1: 1 messages
# Pace_97_ -> Pace_48_: 1 messages
# Pace_63_ -> Pace_26_2: 1 messages
# Pace_57_2 -> Pace_23_2: 1 messages
# Pace_68_1 -> Pace_58_1: 1 messages
# Pace_59_1 -> Pace_68_: 1 messages
# Pace_51_ -> Pace_54_: 1 messages
# Pace_25_2 -> Pace_13_2: 1 messages
# Pace_11_ -> Pace_80_1: 1 messages
# Pace_24_ -> Pace_70_1: 1 messages
# Pace_69_1 -> Pace_44_: 1 messages
# Pace_33_2 -> Pace_40_2: 1 messages
# Pace_93_2 -> Pace_16_: 1 messages
# Pace_95_1 -> Pace_36_1: 1 messages
# Pace_64_ -> Pace_76_1: 1 messages
# Pace_71_ -> Pace_36_2: 1 messages
# Pace_57_ -> Pace_53_1: 1 messages
# Pace_77_2 -> Pace_12_2: 1 messages
# Pace_22_ -> Pace_37_1: 1 messages
# Pace_36_1 -> Pace_24_: 1 messages
# Pace_40_1 -> Pace_66_: 1 messages
# Pace_11_1 -> Pace_62_1: 1 messages
# Pace_30_1 -> Pace_17_1: 1 messages
# Pace_19_ -> Pace_26_1: 1 messages
# Pace_85_2 -> Pace_88_1: 1 messages
# Pace_74_ -> Pace_12_2: 1 messages
# Pace_19_1 -> Pace_40_1: 1 messages
# Pace_28_2 -> Pace_98_: 1 messages
# Pace_85_2 -> Pace_31_1: 1 messages
# Pace_15_1 -> Pace_60_: 1 messages
# Pace_70_2 -> Pace_94_1: 1 messages
# Pace_49_ -> Pace_95_1: 1 messages
# Pace_98_ -> Pace_56_1: 1 messages
# Pace_70_2 -> Pace_34_1: 1 messages
# Pace_47_1 -> Pace_32_: 1 messages
# Pace_93_1 -> Pace_96_1: 1 messages
# Pace_18_ -> Pace_20_: 1 messages
# Pace_21_1 -> Pace_22_1: 1 messages
# Pace_67_ -> Pace_29_1: 1 messages
# Pace_35_1 -> Pace_82_1: 1 messages
# Pace_46_1 -> Pace_36_1: 1 messages
# Pace_88_2 -> Pace_11_: 1 messages
# Pace_77_2 -> Pace_13_2: 1 messages
# Pace_49_ -> Pace_60_1: 1 messages
# Pace_70_1 -> Pace_43_: 2 messages
# Pace_89_ -> Pace_54_1: 1 messages
# Pace_81_ -> Pace_37_2: 1 messages
# Pace_94_2 -> Pace_45_: 1 messages
# Pace_37_2 -> Pace_78_2: 1 messages
# Pace_52_ -> Pace_29_: 1 messages
# Pace_62_ -> Pace_47_: 1 messages
# Pace_50_ -> Pace_64_: 1 messages
# Pace_42_1 -> Pace_24_2: 1 messages
# Pace_81_1 -> Pace_16_: 1 messages
# Pace_60_2 -> Pace_48_2: 1 messages
# Pace_82_ -> Pace_77_1: 1 messages
# Pace_10_2 -> Pace_33_: 1 messages
# Pace_31_ -> Pace_27_1: 1 messages
# Pace_22_1 -> Pace_12_1: 1 messages
# Pace_89_ -> Pace_54_: 1 messages
# Pace_46_1 -> Pace_85_1: 1 messages
# Pace_76_ -> Pace_97_1: 1 messages
# Pace_58_1 -> Pace_44_: 1 messages
# Pace_72_1 -> Pace_78_1: 1 messages
# Pace_41_1 -> Pace_71_2: 1 messages
# Pace_78_1 -> Pace_78_2: 1 messages
# Pace_91_2 -> Pace_70_1: 1 messages
# Pace_60_ -> Pace_62_1: 1 messages
# Pace_46_1 -> Pace_46_: 1 messages
# Pace_43_ -> Pace_95_: 1 messages
# Pace_11_ -> Pace_49_: 1 messages
# Pace_13_1 -> Pace_48_1: 1 messages
# Pace_36_ -> Pace_85_2: 1 messages
# Pace_87_2 -> Pace_34_1: 1 messages
# Pace_28_1 -> Pace_49_1: 1 messages
# Pace_97_1 -> Pace_90_: 1 messages
# Pace_34_ -> Pace_90_: 1 messages
# Pace_30_1 -> Pace_42_2: 1 messages
# Pace_77_ -> Pace_17_1: 1 messages
# Pace_90_ -> Pace_23_: 1 messages
# Pace_95_1 -> Pace_49_: 1 messages
# Pace_34_2 -> Pace_39_1: 1 messages
# Pace_42_1 -> Pace_50_2: 1 messages
# Pace_97_2 -> Pace_61_2: 1 messages
# Pace_74_1 -> Pace_19_2: 1 messages
# Pace_20_ -> Pace_20_: 1 messages
# Pace_91_ -> Pace_50_: 1 messages
# Pace_58_2 -> Pace_31_2: 1 messages
# Pace_60_1 -> Pace_30_2: 1 messages
# Pace_91_2 -> Pace_85_1: 1 messages
# Pace_75_ -> Pace_93_1: 1 messages
# Pace_92_ -> Pace_88_: 1 messages
# Pace_14_ -> Pace_15_1: 1 messages
# Pace_27_1 -> Pace_72_: 1 messages
# Pace_17_ -> Pace_75_1: 1 messages
# Pace_49_1 -> Pace_27_1: 1 messages
# Pace_75_2 -> Pace_72_2: 1 messages
# Pace_56_1 -> Pace_34_2: 1 messages
# Pace_14_ -> Pace_64_1: 1 messages
# Pace_18_2 -> Pace_45_2: 1 messages
# Pace_84_2 -> Pace_45_2: 1 messages
# Pace_26_ -> Pace_52_: 1 messages
# Pace_49_ -> Pace_18_: 1 messages
# Pace_17_1 -> Pace_23_1: 1 messages
# Pace_17_2 -> Pace_13_1: 1 messages
# Pace_35_ -> Pace_82_2: 1 messages
# Pace_29_ -> Pace_37_1: 1 messages
# Pace_69_1 -> Pace_24_2: 1 messages
# Pace_42_ -> Pace_54_1: 1 messages
# Pace_77_1 -> Pace_15_1: 1 messages
# Pace_36_ -> Pace_50_2: 1 messages
# Pace_61_2 -> Pace_41_2: 1 messages
# Pace_33_2 -> Pace_29_: 1 messages
# Pace_76_1 -> Pace_52_2: 1 messages
# Pace_62_1 -> Pace_19_1: 1 messages
# Pace_98_ -> Pace_64_1: 1 messages
# Pace_59_ -> Pace_11_: 1 messages
# Pace_64_ -> Pace_12_2: 1 messages
# Pace_18_ -> Pace_14_1: 1 messages
# Pace_98_ -> Pace_78_1: 1 messages
# Pace_97_1 -> Pace_92_2: 1 messages
# Pace_14_ -> Pace_68_: 1 messages
# Pace_25_ -> Pace_22_: 1 messages
# Pace_17_ -> Pace_30_: 1 messages
# Pace_10_ -> Pace_21_: 1 messages
# Pace_71_2 -> Pace_84_: 1 messages
# Pace_98_1 -> Pace_20_2: 1 messages
# Pace_67_2 -> Pace_86_1: 1 messages
# Pace_12_2 -> Pace_93_2: 1 messages
# Pace_72_ -> Pace_60_1: 1 messages
# Pace_73_ -> Pace_32_2: 1 messages
# Pace_15_1 -> Pace_78_2: 1 messages
# Pace_85_1 -> Pace_88_2: 1 messages
# Pace_83_ -> Pace_74_1: 1 messages
# Pace_48_1 -> Pace_28_2: 1 messages
# Pace_12_1 -> Pace_99_1: 1 messages
# Pace_31_ -> Pace_10_: 1 messages
# Pace_69_2 -> Pace_81_: 1 messages
# Pace_98_1 -> Pace_81_: 1 messages
# Pace_81_2 -> Pace_53_1: 2 messages
# Pace_19_1 -> Pace_13_1: 1 messages
# Pace_31_ -> Pace_88_1: 1 messages
# Pace_82_1 -> Pace_69_1: 1 messages
# Pace_91_ -> Pace_69_: 1 messages
# Pace_13_1 -> Pace_75_: 1 messages
# Pace_91_ -> Pace_70_: 1 messages
# Pace_86_1 -> Pace_17_1: 1 messages
# Pace_47_2 -> Pace_64_: 1 messages
# Pace_46_ -> Pace_15_1: 1 messages
# Pace_25_ -> Pace_27_1: 1 messages
# Pace_85_ -> Pace_20_: 1 messages
# Pace_86_2 -> Pace_89_: 1 messages
# Pace_61_2 -> Pace_63_2: 1 messages
# Pace_42_1 -> Pace_37_1: 1 messages
# Pace_83_2 -> Pace_88_2: 1 messages
# Pace_86_ -> Pace_86_1: 1 messages
# Pace_80_1 -> Pace_92_1: 1 messages
# Pace_18_ -> Pace_64_1: 1 messages
# Pace_33_2 -> Pace_90_1: 1 messages
# Pace_28_ -> Pace_73_: 1 messages
# Pace_47_2 -> Pace_50_: 1 messages
# Pace_87_ -> Pace_36_2: 1 messages
# Pace_65_1 -> Pace_55_1: 1 messages
# Pace_74_1 -> Pace_74_1: 1 messages
# Pace_52_ -> Pace_27_1: 1 messages
# Pace_69_2 -> Pace_48_: 1 messages
# Pace_59_2 -> Pace_45_: 1 messages
# Pace_86_2 -> Pace_95_2: 1 messages
# Pace_30_ -> Pace_63_2: 1 messages
# Pace_19_1 -> Pace_35_1: 1 messages
# Pace_38_2 -> Pace_32_: 1 messages
# Pace_82_ -> Pace_90_: 1 messages
# Pace_33_ -> Pace_86_: 1 messages
# Pace_29_1 -> Pace_58_: 1 messages
# Pace_30_2 -> Pace_23_: 1 messages
# Pace_18_1 -> Pace_39_1: 1 messages
# Pace_36_2 -> Pace_40_: 1 messages
# Pace_53_ -> Pace_99_: 1 messages
# Pace_20_2 -> Pace_38_1: 1 messages
# Pace_63_ -> Pace_23_2: 1 messages
# Pace_11_ -> Pace_43_1: 1 messages
# Pace_90_1 -> Pace_88_: 1 messages
# Pace_91_2 -> Pace_43_1: 1 messages
# Pace_66_1 -> Pace_15_1: 1 messages
# Pace_54_ -> Pace_96_: 1 messages
# Pace_34_1 -> Pace_71_1: 1 messages
# Pace_81_ -> Pace_82_2: 1 messages
# Pace_71_ -> Pace_32_: 1 messages
# Pace_11_1 -> Pace_55_: 1 messages
# Pace_46_1 -> Pace_57_1: 1 messages
# Pace_87_2 -> Pace_29_2: 1 messages
# Pace_93_2 -> Pace_74_1: 1 messages
# Pace_18_1 -> Pace_83_: 1 messages
# Pace_99_1 -> Pace_92_2: 1 messages
# Pace_21_ -> Pace_92_1: 1 messages
# Pace_18_ -> Pace_81_: 1 messages
# Pace_81_ -> Pace_99_2: 1 messages
# Pace_60_2 -> Pace_96_1: 1 messages
# Pace_99_1 -> Pace_78_: 1 messages
# Pace_90_2 -> Pace_40_: 1 messages
# Pace_73_2 -> Pace_66_: 1 messages
# Pace_38_1 -> Pace_39_: 1 messages
# Pace_10_1 -> Pace_82_1: 1 messages
# Pace_57_1 -> Pace_74_2: 1 messages
# Pace_59_ -> Pace_47_: 1 messages
# Pace_60_1 -> Pace_18_1: 1 messages
# Pace_89_2 -> Pace_56_: 1 messages
# Pace_57_1 -> Pace_30_: 1 messages
# Pace_66_ -> Pace_94_2: 1 messages
# Pace_44_1 -> Pace_74_: 1 messages
# Pace_67_ -> Pace_58_: 1 messages
# Pace_99_ -> Pace_27_: 1 messages
# Pace_81_1 -> Pace_26_2: 1 messages
# Pace_16_ -> Pace_56_1: 1 messages
# Pace_30_2 -> Pace_87_1: 1 messages
# Pace_51_1 -> Pace_42_1: 1 messages
# Pace_76_1 -> Pace_45_1: 1 messages
# Pace_71_1 -> Pace_10_: 1 messages
# Pace_29_1 -> Pace_75_1: 1 messages
# Pace_80_1 -> Pace_79_: 1 messages
# Pace_84_1 -> Pace_43_: 1 messages
# Pace_47_ -> Pace_79_1: 1 messages
# Pace_84_2 -> Pace_23_2: 1 messages
# Pace_13_1 -> Pace_19_: 1 messages
# Pace_96_2 -> Pace_18_: 1 messages
# Pace_55_2 -> Pace_52_2: 1 messages
# Pace_72_2 -> Pace_40_1: 1 messages
# Pace_83_ -> Pace_87_1: 1 messages
# Pace_45_2 -> Pace_24_2: 1 messages
# Pace_74_1 -> Pace_46_: 1 messages
# Pace_27_1 -> Pace_38_1: 1 messages
# Pace_75_1 -> Pace_82_: 1 messages
# Pace_40_2 -> Pace_89_1: 1 messages
# Pace_50_1 -> Pace_84_: 1 messages
# Pace_86_1 -> Pace_80_: 1 messages
# Pace_60_1 -> Pace_23_1: 1 messages
# Pace_89_1 -> Pace_75_1: 1 messages
# Pace_59_1 -> Pace_42_2: 1 messages
# Pace_53_1 -> Pace_39_1: 1 messages
# Pace_75_2 -> Pace_66_: 1 messages
# Pace_88_ -> Pace_84_: 1 messages
# Pace_84_1 -> Pace_71_2: 1 messages
# Pace_63_2 -> Pace_77_: 1 messages
# Pace_83_2 -> Pace_75_1: 1 messages
# Pace_68_2 -> Pace_60_2: 1 messages
# Pace_92_1 -> Pace_88_: 1 messages
# Pace_96_1 -> Pace_69_2: 1 messages
# Pace_47_ -> Pace_62_: 1 messages
# Pace_36_2 -> Pace_17_2: 1 messages
# Pace_25_1 -> Pace_22_1: 1 messages
# Pace_44_2 -> Pace_76_1: 1 messages
# Pace_72_2 -> Pace_21_1: 1 messages
# Pace_60_2 -> Pace_64_: 1 messages
# Pace_39_2 -> Pace_98_: 1 messages
# Pace_66_1 -> Pace_96_1: 1 messages
# Pace_34_ -> Pace_41_2: 1 messages
# Pace_90_ -> Pace_46_1: 1 messages
# Pace_14_1 -> Pace_54_1: 1 messages
# Pace_62_1 -> Pace_99_1: 1 messages
# Pace_43_2 -> Pace_44_2: 1 messages
# Pace_23_ -> Pace_91_1: 1 messages
# Pace_56_2 -> Pace_43_1: 1 messages
# Pace_85_ -> Pace_23_: 1 messages
# Pace_99_1 -> Pace_27_1: 1 messages
# Pace_65_1 -> Pace_90_1: 1 messages
# Pace_39_1 -> Pace_98_1: 1 messages
# Pace_45_ -> Pace_39_: 1 messages
# Pace_92_1 -> Pace_28_1: 1 messages
# Pace_70_1 -> Pace_10_: 1 messages
# Pace_67_1 -> Pace_84_1: 1 messages
# Pace_50_1 -> Pace_89_1: 1 messages
# Pace_23_1 -> Pace_25_1: 1 messages
# Pace_31_2 -> Pace_67_2: 1 messages
# Pace_33_2 -> Pace_74_2: 1 messages
# Pace_87_2 -> Pace_43_1: 1 messages
# Pace_23_2 -> Pace_71_1: 1 messages
# Pace_44_2 -> Pace_64_1: 1 messages
# Pace_67_1 -> Pace_26_2: 1 messages
# Pace_51_ -> Pace_31_1: 1 messages
# Pace_20_2 -> Pace_27_: 1 messages
# Pace_40_1 -> Pace_98_: 1 messages
# Pace_93_ -> Pace_78_1: 1 messages
# Pace_93_1 -> Pace_55_: 1 messages
# Pace_28_1 -> Pace_58_1: 1 messages
# Pace_29_1 -> Pace_13_2: 1 messages
# Pace_21_1 -> Pace_66_1: 1 messages
# Pace_63_2 -> Pace_12_2: 1 messages
# Pace_44_ -> Pace_89_1: 1 messages
# Pace_50_1 -> Pace_53_: 1 messages
# Pace_42_2 -> Pace_57_: 1 messages
# Pace_78_1 -> Pace_21_1: 1 messages
# Pace_96_ -> Pace_86_: 2 messages
# Pace_61_2 -> Pace_88_1: 1 messages
# Pace_89_ -> Pace_55_: 1 messages
# Pace_16_1 -> Pace_28_: 1 messages
# Pace_71_1 -> Pace_10_2: 1 messages
# Pace_80_1 -> Pace_41_1: 1 messages
# Pace_31_1 -> Pace_33_: 1 messages
# Pace_88_ -> Pace_94_2: 1 messages
# Pace_62_1 -> Pace_77_: 1 messages
# Pace_29_ -> Pace_30_1: 1 messages
# Pace_18_ -> Pace_87_2: 1 messages
# Pace_60_1 -> Pace_45_: 1 messages
# Pace_14_2 -> Pace_60_2: 1 messages
# Pace_22_1 -> Pace_30_: 1 messages
# Pace_70_2 -> Pace_62_1: 1 messages
# Pace_88_2 -> Pace_68_1: 1 messages
# Pace_39_2 -> Pace_45_: 1 messages
# Pace_11_ -> Pace_58_: 1 messages
# Pace_82_1 -> Pace_27_1: 1 messages
# Pace_24_ -> Pace_95_: 1 messages
# Pace_27_ -> Pace_27_: 1 messages
# Pace_54_ -> Pace_85_1: 1 messages
# Pace_99_ -> Pace_28_1: 1 messages
# Pace_28_ -> Pace_43_: 1 messages
# Pace_68_1 -> Pace_64_: 1 messages
# Pace_87_ -> Pace_24_2: 1 messages
# Pace_69_2 -> Pace_64_1: 1 messages
# Pace_16_ -> Pace_92_2: 1 messages
# Pace_52_ -> Pace_10_: 1 messages
# Pace_33_2 -> Pace_46_: 2 messages
# Pace_57_1 -> Pace_20_1: 1 messages
# Pace_29_1 -> Pace_50_1: 1 messages
# Pace_29_1 -> Pace_86_: 1 messages
# Pace_40_1 -> Pace_45_1: 1 messages
# Pace_63_1 -> Pace_96_1: 1 messages
# Pace_59_ -> Pace_46_: 1 messages
# Pace_97_1 -> Pace_91_1: 1 messages
# Pace_24_ -> Pace_18_: 1 messages
# Pace_75_1 -> Pace_51_: 1 messages
# Pace_84_2 -> Pace_64_2: 1 messages
# Pace_34_2 -> Pace_22_: 1 messages
# Pace_27_ -> Pace_72_2: 1 messages
# Pace_98_2 -> Pace_60_2: 1 messages
# Pace_34_1 -> Pace_55_: 1 messages
# Pace_72_1 -> Pace_86_1: 1 messages
# Pace_35_ -> Pace_16_1: 1 messages
# Pace_14_1 -> Pace_46_1: 1 messages
# Pace_26_1 -> Pace_23_2: 1 messages
# Pace_50_ -> Pace_79_1: 1 messages
# Pace_76_ -> Pace_27_: 1 messages
# Pace_37_1 -> Pace_95_: 1 messages
# Pace_52_1 -> Pace_42_1: 1 messages
# Pace_50_1 -> Pace_23_1: 1 messages
# Pace_57_ -> Pace_90_1: 1 messages
# Pace_44_2 -> Pace_79_: 1 messages
# Pace_33_ -> Pace_77_: 1 messages
# Pace_20_2 -> Pace_34_1: 1 messages
# Pace_42_ -> Pace_93_2: 1 messages
# Pace_63_1 -> Pace_15_2: 1 messages
# Pace_14_2 -> Pace_16_: 1 messages
# Pace_12_2 -> Pace_17_1: 1 messages
# Pace_46_ -> Pace_72_: 1 messages
# Pace_32_ -> Pace_89_: 1 messages
# Pace_76_2 -> Pace_51_1: 1 messages
# Pace_28_1 -> Pace_43_1: 1 messages
# Pace_24_ -> Pace_58_1: 1 messages
# Pace_46_ -> Pace_75_: 1 messages
# Pace_96_1 -> Pace_51_2: 1 messages
# Pace_75_2 -> Pace_92_2: 1 messages
# Pace_33_ -> Pace_12_1: 1 messages
# Pace_55_1 -> Pace_84_: 1 messages
# Pace_40_1 -> Pace_31_2: 1 messages
# Pace_67_2 -> Pace_49_1: 1 messages
# Pace_67_ -> Pace_28_: 1 messages
# Pace_41_ -> Pace_57_1: 1 messages
# Pace_73_1 -> Pace_29_: 1 messages
# Pace_73_1 -> Pace_82_1: 1 messages
# Pace_35_ -> Pace_77_1: 1 messages
# Pace_85_2 -> Pace_89_1: 1 messages
# Pace_88_1 -> Pace_83_1: 1 messages
# Pace_71_1 -> Pace_24_1: 1 messages
# Pace_77_ -> Pace_38_1: 1 messages
# Pace_67_1 -> Pace_79_: 1 messages
# Pace_97_2 -> Pace_14_1: 1 messages
# Pace_80_ -> Pace_15_2: 1 messages
# Pace_48_1 -> Pace_58_: 1 messages
# Pace_66_1 -> Pace_43_1: 1 messages
# Pace_64_1 -> Pace_52_: 1 messages
# Pace_42_ -> Pace_86_1: 1 messages
# Pace_72_1 -> Pace_11_1: 1 messages
# Pace_55_ -> Pace_61_1: 1 messages
# Pace_39_ -> Pace_37_1: 2 messages
# Pace_57_1 -> Pace_28_: 1 messages
# Pace_80_1 -> Pace_34_1: 1 messages
# Pace_16_1 -> Pace_69_2: 1 messages
# Pace_24_ -> Pace_40_2: 1 messages
# Pace_96_ -> Pace_47_: 1 messages
# Pace_73_1 -> Pace_93_1: 1 messages
# Pace_63_ -> Pace_96_1: 1 messages
# Pace_34_1 -> Pace_78_1: 1 messages
# Pace_67_1 -> Pace_59_1: 1 messages
# Pace_23_1 -> Pace_34_2: 1 messages
# Pace_90_ -> Pace_41_: 1 messages
# Pace_37_2 -> Pace_10_: 1 messages
# Pace_79_2 -> Pace_49_1: 1 messages
# Pace_66_ -> Pace_42_1: 1 messages
# Pace_97_2 -> Pace_90_1: 1 messages
# Pace_10_1 -> Pace_12_2: 1 messages
# Pace_79_2 -> Pace_92_1: 1 messages
# Pace_64_ -> Pace_11_: 1 messages
# Pace_34_ -> Pace_14_1: 1 messages
# Pace_78_ -> Pace_49_2: 1 messages
# Pace_61_ -> Pace_12_: 1 messages
# Pace_52_1 -> Pace_71_: 1 messages
# Pace_53_1 -> Pace_62_2: 1 messages
# Pace_47_2 -> Pace_12_1: 2 messages
# Pace_67_ -> Pace_69_2: 1 messages
# Pace_70_1 -> Pace_80_1: 1 messages
# Pace_34_2 -> Pace_10_1: 1 messages
# Pace_48_1 -> Pace_62_: 1 messages
# Pace_77_ -> Pace_55_1: 1 messages
# Pace_31_1 -> Pace_68_1: 1 messages
# Pace_85_ -> Pace_59_1: 1 messages
# Pace_68_1 -> Pace_18_1: 1 messages
# Pace_93_ -> Pace_82_2: 1 messages
# Pace_42_1 -> Pace_66_1: 1 messages
# Pace_71_2 -> Pace_64_1: 1 messages
# Pace_35_ -> Pace_11_1: 1 messages
# Pace_67_1 -> Pace_12_1: 1 messages
# Pace_17_1 -> Pace_58_1: 1 messages
# Pace_13_1 -> Pace_72_1: 1 messages
# Pace_35_1 -> Pace_56_2: 1 messages
# Pace_90_1 -> Pace_70_: 1 messages
# Pace_89_ -> Pace_39_2: 1 messages
# Pace_12_2 -> Pace_97_: 1 messages
# Pace_55_ -> Pace_14_1: 1 messages
# Pace_99_ -> Pace_11_: 1 messages
# Pace_38_2 -> Pace_37_2: 1 messages
# Pace_72_1 -> Pace_90_2: 1 messages
# Pace_32_ -> Pace_11_1: 1 messages
# Pace_81_1 -> Pace_79_: 1 messages
# Pace_78_ -> Pace_48_: 1 messages
# Pace_35_2 -> Pace_48_: 1 messages
# Pace_38_2 -> Pace_14_1: 1 messages
# Pace_34_1 -> Pace_11_2: 1 messages
# Pace_79_1 -> Pace_39_: 1 messages
# Pace_80_ -> Pace_57_1: 1 messages
# Pace_94_ -> Pace_46_1: 1 messages
# Pace_13_1 -> Pace_28_1: 1 messages
# Pace_28_ -> Pace_13_: 1 messages
# Pace_52_1 -> Pace_61_: 1 messages
# Pace_46_1 -> Pace_15_1: 1 messages
# Pace_93_ -> Pace_59_: 1 messages
# Pace_40_ -> Pace_62_2: 1 messages
# Pace_46_ -> Pace_37_: 1 messages
# Pace_63_ -> Pace_40_2: 1 messages
# Pace_72_1 -> Pace_82_1: 1 messages
# Pace_42_ -> Pace_88_: 1 messages
# Pace_39_1 -> Pace_57_2: 1 messages
# Pace_58_1 -> Pace_63_2: 1 messages
# Pace_64_ -> Pace_44_1: 1 messages
# Pace_60_2 -> Pace_26_: 1 messages
# Pace_99_2 -> Pace_72_2: 1 messages
# Pace_47_ -> Pace_42_1: 1 messages
# Pace_26_ -> Pace_69_1: 1 messages
# Pace_31_2 -> Pace_37_2: 1 messages
# Pace_18_1 -> Pace_48_2: 1 messages
# Pace_75_1 -> Pace_22_: 1 messages
# Pace_73_ -> Pace_33_: 1 messages
# Pace_51_1 -> Pace_56_1: 1 messages
# Pace_99_1 -> Pace_83_1: 1 messages
# Pace_93_ -> Pace_70_1: 1 messages
# Pace_85_1 -> Pace_58_2: 1 messages
# Pace_63_ -> Pace_32_: 1 messages
# Pace_45_ -> Pace_54_1: 1 messages
# Pace_93_1 -> Pace_16_1: 1 messages
# Pace_47_2 -> Pace_24_: 1 messages
# Pace_78_2 -> Pace_82_1: 1 messages
# Pace_34_ -> Pace_23_1: 1 messages
# Pace_51_1 -> Pace_39_1: 1 messages
# Pace_63_ -> Pace_63_1: 1 messages
# Pace_43_1 -> Pace_62_: 1 messages
# Pace_14_2 -> Pace_84_2: 1 messages
# Pace_50_ -> Pace_97_2: 1 messages
# Pace_47_ -> Pace_21_2: 1 messages
# Pace_82_ -> Pace_87_: 1 messages
# Pace_28_ -> Pace_91_1: 1 messages
# Pace_18_1 -> Pace_20_: 1 messages
# Pace_91_1 -> Pace_91_2: 1 messages
# Pace_54_ -> Pace_14_: 1 messages
# Pace_52_ -> Pace_88_: 1 messages
# Pace_60_1 -> Pace_16_2: 1 messages
# Pace_86_2 -> Pace_12_1: 1 messages
# Pace_99_ -> Pace_96_1: 2 messages
# Pace_80_1 -> Pace_63_1: 1 messages
# Pace_81_2 -> Pace_55_2: 1 messages
# Pace_43_ -> Pace_98_: 1 messages
# Pace_76_1 -> Pace_67_1: 1 messages
# Pace_93_2 -> Pace_28_1: 1 messages
# Pace_92_1 -> Pace_42_1: 1 messages
# Pace_40_1 -> Pace_75_: 1 messages
# Pace_40_1 -> Pace_56_2: 1 messages
# Pace_50_1 -> Pace_46_1: 1 messages
# Pace_25_1 -> Pace_75_: 1 messages
# Pace_98_1 -> Pace_93_2: 1 messages
# Pace_13_1 -> Pace_82_1: 1 messages
# Pace_85_2 -> Pace_36_: 1 messages
# Pace_85_ -> Pace_87_1: 1 messages
# Pace_39_2 -> Pace_71_1: 1 messages
# Pace_50_1 -> Pace_30_1: 1 messages
# Pace_23_ -> Pace_84_1: 1 messages
# Pace_30_ -> Pace_23_1: 1 messages
# Pace_64_ -> Pace_65_: 1 messages
# Pace_73_1 -> Pace_45_: 1 messages
# Pace_27_ -> Pace_43_1: 2 messages
# Pace_81_ -> Pace_87_: 1 messages
# Pace_57_2 -> Pace_80_: 1 messages
# Pace_19_1 -> Pace_39_2: 1 messages
# Pace_12_2 -> Pace_89_2: 1 messages
# Pace_86_2 -> Pace_81_2: 1 messages
# Pace_54_1 -> Pace_12_2: 1 messages
# Pace_48_2 -> Pace_72_1: 1 messages
# Pace_79_ -> Pace_74_1: 1 messages
# Pace_75_2 -> Pace_56_1: 1 messages
# Pace_27_1 -> Pace_19_1: 1 messages
# Pace_25_2 -> Pace_38_1: 1 messages
# Pace_98_ -> Pace_81_: 1 messages
# Pace_49_1 -> Pace_59_1: 1 messages
# Pace_40_1 -> Pace_56_1: 1 messages
# Pace_50_1 -> Pace_81_2: 1 messages
# Pace_49_1 -> Pace_77_2: 1 messages
# Pace_84_2 -> Pace_12_1: 1 messages
# Pace_53_ -> Pace_45_1: 1 messages
# Pace_48_ -> Pace_90_: 1 messages
# Pace_88_ -> Pace_22_1: 1 messages
# Pace_84_ -> Pace_15_1: 1 messages
# Pace_37_ -> Pace_46_: 1 messages
# Pace_23_ -> Pace_53_2: 1 messages
# Pace_73_1 -> Pace_88_1: 1 messages
# Pace_78_1 -> Pace_91_: 1 messages
# Pace_48_2 -> Pace_59_2: 1 messages
# Pace_46_1 -> Pace_53_2: 1 messages
# Pace_88_1 -> Pace_53_: 1 messages
# Pace_49_1 -> Pace_39_: 1 messages
# Pace_19_ -> Pace_98_1: 1 messages
# Pace_46_2 -> Pace_90_2: 1 messages
# Pace_94_ -> Pace_79_1: 1 messages
# Pace_33_ -> Pace_32_: 1 messages
# Pace_91_2 -> Pace_13_: 1 messages
# Pace_45_ -> Pace_76_1: 1 messages
# Pace_38_1 -> Pace_90_2: 1 messages
# Pace_55_ -> Pace_78_1: 1 messages
# Pace_42_1 -> Pace_44_2: 1 messages
# Pace_19_1 -> Pace_10_: 1 messages
# Pace_90_1 -> Pace_74_1: 1 messages
# Pace_83_ -> Pace_89_1: 1 messages
# Pace_92_2 -> Pace_99_2: 1 messages
# Pace_41_2 -> Pace_50_1: 1 messages
# Pace_41_1 -> Pace_56_1: 1 messages
# Pace_53_ -> Pace_96_: 1 messages
# Pace_27_1 -> Pace_37_1: 1 messages
# Pace_32_ -> Pace_58_: 1 messages
# Pace_84_ -> Pace_99_1: 1 messages
# Pace_10_2 -> Pace_73_1: 1 messages
# Pace_20_2 -> Pace_51_2: 1 messages
# Pace_98_2 -> Pace_80_: 1 messages
# Pace_28_2 -> Pace_40_: 1 messages
# Pace_16_1 -> Pace_52_: 1 messages
# Pace_70_1 -> Pace_75_: 1 messages
# Pace_51_ -> Pace_50_2: 1 messages
# Pace_69_ -> Pace_91_: 1 messages
# Pace_19_ -> Pace_12_1: 1 messages
# Pace_14_ -> Pace_16_1: 1 messages
# Pace_40_ -> Pace_32_2: 1 messages
# Pace_29_1 -> Pace_10_2: 1 messages
# Pace_34_2 -> Pace_27_: 1 messages
# Pace_67_1 -> Pace_75_: 1 messages
# Pace_12_ -> Pace_18_: 1 messages
# Pace_33_1 -> Pace_15_: 1 messages
# Pace_14_ -> Pace_51_1: 1 messages
# Pace_87_2 -> Pace_39_1: 1 messages
# Pace_34_ -> Pace_71_: 1 messages
# Pace_39_ -> Pace_66_1: 1 messages
# Pace_32_ -> Pace_15_: 1 messages
# Pace_85_1 -> Pace_11_1: 1 messages
# Pace_81_ -> Pace_79_2: 1 messages
# Pace_96_1 -> Pace_93_1: 1 messages
# Pace_71_ -> Pace_45_1: 1 messages
# Pace_92_ -> Pace_46_2: 1 messages
# Pace_76_1 -> Pace_74_1: 1 messages
# Pace_58_1 -> Pace_49_1: 1 messages
# Pace_51_ -> Pace_53_1: 1 messages
# Pace_61_ -> Pace_23_: 1 messages
# Pace_26_1 -> Pace_27_: 1 messages
# Pace_22_ -> Pace_78_2: 1 messages
# Pace_39_ -> Pace_38_1: 1 messages
# Pace_66_2 -> Pace_48_1: 1 messages
# Pace_51_ -> Pace_94_2: 1 messages
# Pace_62_2 -> Pace_24_1: 1 messages
# Pace_98_ -> Pace_16_2: 1 messages
# Pace_36_1 -> Pace_60_: 1 messages
# Pace_53_1 -> Pace_11_2: 1 messages
# Pace_77_ -> Pace_59_1: 1 messages
# Pace_19_ -> Pace_39_2: 1 messages
# Pace_16_ -> Pace_53_: 1 messages
# Pace_18_2 -> Pace_34_1: 1 messages
# Pace_71_ -> Pace_52_1: 1 messages
# Pace_12_1 -> Pace_93_: 1 messages
# Pace_87_ -> Pace_69_: 1 messages
# Pace_69_2 -> Pace_48_2: 1 messages
# Pace_88_1 -> Pace_44_1: 1 messages
# Pace_29_ -> Pace_42_: 1 messages
# Pace_90_ -> Pace_41_2: 1 messages
# Pace_28_ -> Pace_89_1: 1 messages
# Pace_56_ -> Pace_17_2: 1 messages
# Pace_66_ -> Pace_78_: 1 messages
# Pace_56_ -> Pace_14_2: 1 messages
# Pace_58_ -> Pace_85_1: 1 messages
# Pace_55_1 -> Pace_13_: 1 messages
# Pace_91_1 -> Pace_19_1: 1 messages
# Pace_95_2 -> Pace_74_1: 1 messages
# Pace_16_1 -> Pace_74_1: 1 messages
# Pace_26_2 -> Pace_53_1: 1 messages
# Pace_17_ -> Pace_16_1: 1 messages
# Pace_85_2 -> Pace_93_2: 1 messages
# Pace_45_2 -> Pace_32_1: 1 messages
# Pace_79_1 -> Pace_26_: 1 messages
# Pace_93_ -> Pace_87_: 1 messages
# Pace_62_1 -> Pace_81_1: 1 messages
# Pace_22_ -> Pace_20_1: 1 messages
# Pace_81_1 -> Pace_19_1: 1 messages
# Pace_67_2 -> Pace_74_2: 1 messages
# Pace_89_1 -> Pace_11_2: 1 messages
# Pace_16_1 -> Pace_19_1: 1 messages
# Pace_46_ -> Pace_86_1: 1 messages
# Pace_44_ -> Pace_75_1: 1 messages
# Pace_32_2 -> Pace_34_1: 1 messages
# Pace_81_ -> Pace_39_2: 1 messages
# Pace_89_2 -> Pace_16_: 1 messages
# Pace_28_1 -> Pace_35_: 1 messages
# Pace_14_2 -> Pace_18_1: 1 messages
# Pace_47_1 -> Pace_78_: 1 messages
# Pace_20_ -> Pace_46_1: 1 messages
# Pace_85_ -> Pace_64_1: 1 messages
# Pace_46_1 -> Pace_69_2: 1 messages
# Pace_47_2 -> Pace_60_1: 1 messages
# Pace_75_2 -> Pace_30_1: 1 messages
# Pace_52_2 -> Pace_68_2: 1 messages
# Pace_65_1 -> Pace_82_: 1 messages
# Pace_91_ -> Pace_34_2: 1 messages
# Pace_62_1 -> Pace_61_: 1 messages
# Pace_84_1 -> Pace_95_: 1 messages
# Pace_93_ -> Pace_28_1: 1 messages
# Pace_56_1 -> Pace_41_2: 1 messages
# Pace_59_ -> Pace_53_1: 1 messages
# Pace_35_1 -> Pace_37_1: 1 messages
# Pace_14_ -> Pace_56_1: 1 messages
# Pace_88_ -> Pace_34_1: 1 messages
# Pace_70_ -> Pace_94_1: 1 messages
# Pace_45_1 -> Pace_36_2: 1 messages
# Pace_67_1 -> Pace_39_1: 1 messages
# Pace_38_1 -> Pace_40_1: 1 messages
# Pace_42_1 -> Pace_91_: 1 messages
# Pace_40_ -> Pace_14_: 1 messages
# Pace_43_1 -> Pace_36_2: 1 messages
# Pace_88_ -> Pace_21_2: 1 messages
# Pace_16_ -> Pace_49_1: 1 messages
# Pace_11_ -> Pace_66_1: 1 messages
# Pace_27_1 -> Pace_74_1: 1 messages
# Pace_86_ -> Pace_55_: 1 messages
# Pace_20_ -> Pace_66_: 1 messages
# Pace_21_ -> Pace_26_: 1 messages
# Pace_31_2 -> Pace_19_: 1 messages
# Pace_82_1 -> Pace_58_: 1 messages
# Pace_26_2 -> Pace_49_1: 1 messages
# Pace_66_ -> Pace_90_: 1 messages
# Pace_84_ -> Pace_98_: 1 messages
# Pace_69_ -> Pace_88_1: 1 messages
# Pace_70_ -> Pace_53_: 1 messages
# Pace_71_ -> Pace_88_: 1 messages
# Pace_70_2 -> Pace_51_1: 1 messages
# Pace_24_1 -> Pace_54_: 1 messages
# Pace_12_1 -> Pace_95_2: 1 messages
# Pace_25_ -> Pace_96_1: 1 messages
# Pace_57_ -> Pace_17_2: 1 messages
# Pace_38_ -> Pace_61_: 1 messages
# Pace_62_ -> Pace_57_2: 1 messages
# Pace_47_ -> Pace_98_: 1 messages
# Pace_96_ -> Pace_49_2: 1 messages
# Pace_11_2 -> Pace_31_1: 1 messages
# Pace_93_1 -> Pace_69_2: 1 messages
# Pace_78_ -> Pace_52_2: 1 messages
# Pace_42_1 -> Pace_99_1: 1 messages
# Pace_17_2 -> Pace_78_: 1 messages
# Pace_28_ -> Pace_29_: 1 messages
# Pace_45_ -> Pace_31_: 1 messages
# Pace_81_ -> Pace_38_2: 1 messages
# Pace_18_1 -> Pace_95_1: 1 messages
# Pace_45_ -> Pace_16_1: 1 messages
# Pace_42_2 -> Pace_11_: 1 messages
# Pace_28_2 -> Pace_49_1: 1 messages
# Pace_66_1 -> Pace_56_2: 1 messages
# Pace_97_1 -> Pace_40_1: 1 messages
# Pace_32_1 -> Pace_19_1: 1 messages
# Pace_30_1 -> Pace_37_1: 1 messages
# Pace_15_2 -> Pace_43_: 1 messages
# Pace_73_1 -> Pace_88_2: 1 messages
# Pace_31_ -> Pace_67_2: 1 messages
# Pace_78_1 -> Pace_27_2: 1 messages
# Pace_64_1 -> Pace_73_1: 1 messages
# Pace_84_1 -> Pace_24_: 1 messages
# Pace_26_ -> Pace_57_: 1 messages
# Pace_20_2 -> Pace_15_2: 1 messages
# Pace_61_ -> Pace_20_2: 1 messages
# Pace_38_1 -> Pace_64_2: 1 messages
# Pace_95_2 -> Pace_73_1: 1 messages
# Pace_98_2 -> Pace_12_2: 1 messages
# Pace_18_2 -> Pace_55_1: 1 messages
# Pace_59_ -> Pace_93_1: 1 messages
# Pace_94_ -> Pace_50_2: 1 messages
# Pace_79_1 -> Pace_84_: 1 messages
# Pace_83_1 -> Pace_41_1: 1 messages
# Pace_23_ -> Pace_61_: 1 messages
# Pace_55_2 -> Pace_31_1: 1 messages
# Pace_74_1 -> Pace_87_2: 1 messages
# Pace_14_ -> Pace_49_: 1 messages
# Pace_69_ -> Pace_73_: 1 messages
# Pace_78_2 -> Pace_92_2: 1 messages
# Pace_86_1 -> Pace_44_2: 1 messages
# Pace_13_ -> Pace_30_1: 1 messages
# Pace_59_1 -> Pace_13_: 1 messages
# Pace_34_1 -> Pace_95_: 1 messages
# Pace_51_2 -> Pace_39_: 1 messages
# Pace_50_2 -> Pace_83_1: 1 messages
# Pace_25_1 -> Pace_74_: 1 messages
# Pace_77_ -> Pace_23_1: 1 messages
# Pace_74_ -> Pace_45_: 1 messages
# Pace_88_2 -> Pace_95_2: 1 messages
# Pace_80_ -> Pace_47_1: 1 messages
# Pace_21_1 -> Pace_61_1: 1 messages
# Pace_57_ -> Pace_51_2: 1 messages
# Pace_86_ -> Pace_98_1: 1 messages
# Pace_22_2 -> Pace_48_: 1 messages
# Pace_66_1 -> Pace_46_1: 1 messages
# Pace_41_1 -> Pace_63_1: 1 messages
# Pace_95_ -> Pace_31_2: 1 messages
# Pace_78_1 -> Pace_64_1: 1 messages
# Pace_41_1 -> Pace_47_1: 1 messages
# Pace_59_1 -> Pace_39_1: 1 messages
# Pace_20_ -> Pace_49_2: 1 messages
# Pace_87_2 -> Pace_18_: 1 messages
# Pace_28_ -> Pace_45_2: 1 messages
# Pace_33_2 -> Pace_25_2: 1 messages
# Pace_11_2 -> Pace_15_1: 1 messages
# Pace_48_ -> Pace_89_: 1 messages
# Pace_65_2 -> Pace_46_1: 1 messages
# Pace_12_1 -> Pace_86_: 1 messages
# Pace_43_1 -> Pace_42_1: 1 messages
# Pace_49_2 -> Pace_29_1: 1 messages
# Pace_77_ -> Pace_25_2: 1 messages
# Pace_70_2 -> Pace_43_: 1 messages
# Pace_41_1 -> Pace_69_: 1 messages
# Pace_51_2 -> Pace_77_1: 1 messages
# Pace_80_ -> Pace_75_2: 1 messages
# Pace_69_ -> Pace_94_: 1 messages
# Pace_68_1 -> Pace_39_2: 1 messages
# Pace_98_2 -> Pace_32_: 1 messages
# Pace_48_ -> Pace_70_: 1 messages
# Pace_98_2 -> Pace_18_: 1 messages
# Pace_82_2 -> Pace_22_: 1 messages
#
#  Message Content Analysis
# Message Subjects and their Counts:
# Students: 197
# Grading: 203
# Curriculum: 216
# Attendance: 183
# Testing: 201
#
#  Date Time Groups Analysis
# Log Entries by Date:
# Mon: 154 entries
# Sat: 165 entries
# Tue: 182 entries
# Fri: 176 entries
# Sun: 174 entries
# Wed: 149 entries
